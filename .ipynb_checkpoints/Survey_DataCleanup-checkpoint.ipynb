# %%
import pandas as pd
import numpy as np

# %%
csv_file = "FAZA2_SOSCI_BACKUP.csv"
df = pd.read_csv(csv_file, index_col=False, sep=',', encoding="utf16")

# %%
df.head()
# Out:
#                          CASE                       SERIAL  \
# 0  Interview number (ongoing)  Serial number (if provided)
# 1                          87                          NaN
# 2                          93                          NaN
# 3                          94                          NaN
# 4                          95                          NaN
#
#                                REF  \
# 0  Reference (if provided in link)
# 1                              NaN
# 2                              NaN
# 3                              NaN
# 4                              NaN
#
#                                             QUESTNNR            MODE  \
# 0  Questionnaire that has been used in the interview  Interview mode
# 1                                               base       interview
# 2                                               base       interview
# 3                                               base       interview
# 4                                               base       interview
#
#                                           STARTED DE01       DE02_01  \
# 0  Time the interview has started (Europe/Berlin)  Pol  Godine: [01]
# 1                             2022-03-09 22:45:05    2            19
# 2                             2022-03-10 01:25:20    2            19
# 3                             2022-03-10 08:44:13    2            19
# 4                             2022-03-10 08:58:16    1            20
#
#           DE03       PF02  ...  \
# 0  Obrazovanje  Alchemist  ...
# 1            3          2  ...
# 2            3          2  ...
# 3            3          1  ...
# 4            3          2  ...
#
#                                             MAILSENT  \
# 0  Time when the invitation mailing was sent (per...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                        LASTDATA  \
# 0  Time when the data was most recently updated
# 1                           2022-03-09 22:49:05
# 2                           2022-03-10 01:30:57
# 3                           2022-03-10 08:51:32
# 4                           2022-03-10 09:08:39
#
#                                             FINISHED  \
# 0  Has the interview been finished (reached last ...
# 1                                                  0
# 2                                                  1
# 3                                                  1
# 4                                                  1
#
#                                             Q_VIEWER  \
# 0  Did the respondent only view the questionnaire...
# 1                                                  0
# 2                                                  0
# 3                                                  0
# 4                                                  0
#
#                                             LASTPAGE  \
# 0  Last page that the participant has handled in ...
# 1                                                 10
# 2                                                 11
# 3                                                 11
# 4                                                 11
#
#                                     MAXPAGE                     MISSING  \
# 0  Hindmost page handled by the participant  Missing answers in percent
# 1                                        10                           0
# 2                                        11                           0
# 3                                        11                           0
# 4                                        11                           0
#
#                                    MISSREL  \
# 0  Missing answers (weighted by relevance)
# 1                                        0
# 2                                        0
# 3                                        0
# 4                                        0
#
#                                  TIME_RSI  \
# 0  Degradation points for being very fast
# 1                                    1.09
# 2                                    0.74
# 3                                    0.62
# 4                                    0.74
#
#                                  DEG_TIME
# 0  Degradation points for being very fast
# 1                                      18
# 2                                       2
# 3                                       1
# 4                                       0
#
# [5 rows x 38 columns]

# %%
df.columns
# Out:
# Index(['CASE', 'SERIAL', 'REF', 'QUESTNNR', 'MODE', 'STARTED', 'DE01',
#        'DE02_01', 'DE03', 'PF02', 'PF04', 'PF07', 'NF01', 'NF03', 'NF05',
#        'NF06', 'TIME001', 'TIME002', 'TIME003', 'TIME004', 'TIME005',
#        'TIME006', 'TIME007', 'TIME008', 'TIME009', 'TIME010', 'TIME011',
#        'TIME_SUM', 'MAILSENT', 'LASTDATA', 'FINISHED', 'Q_VIEWER', 'LASTPAGE',
#        'MAXPAGE', 'MISSING', 'MISSREL', 'TIME_RSI', 'DEG_TIME'],
#       dtype='object')

# %%
relevant_columns = ['CASE', 'DE01', 'LASTDATA',
       'DE02_01', 'DE03', 'PF02', 'PF04', 'PF07', 'NF01', 'NF03', 'NF05', 'NF06',
        'TIME004', 'TIME005', 'TIME006', 'TIME007', 'TIME008', 'TIME009', 'TIME010']

# %%
df = df[relevant_columns]

# %%
df.head()
# Out:
#                          CASE DE01  \
# 0  Interview number (ongoing)  Pol
# 1                          87    2
# 2                          93    2
# 3                          94    2
# 4                          95    1
#
#                                        LASTDATA       DE02_01         DE03  \
# 0  Time when the data was most recently updated  Godine: [01]  Obrazovanje
# 1                           2022-03-09 22:49:05            19            3
# 2                           2022-03-10 01:30:57            19            3
# 3                           2022-03-10 08:51:32            19            3
# 4                           2022-03-10 09:08:39            20            3
#
#         PF02             PF04       PF07     NF01       NF03  \
# 0  Alchemist  Weapons auction  Town hero  Guard N  Butcher N
# 1          2                2          2        1          1
# 2          2                1          2        2          2
# 3          1                2          2        2          1
# 4          2                2          1        1          1
#
#                   NF05        NF06               TIME004  \
# 0  Bandit chase over N  Hospital N  Time spent on page 4
# 1                    1           2                    46
# 2                    1           1                    56
# 3                    2           1                    71
# 4                    1           1                    26
#
#                 TIME005               TIME006               TIME007  \
# 0  Time spent on page 5  Time spent on page 6  Time spent on page 7
# 1                    27                    32                    27
# 2                    55                    27                    44
# 3                    28                    57                    44
# 4                    35                    43                    26
#
#                 TIME008               TIME009                TIME010
# 0  Time spent on page 8  Time spent on page 9  Time spent on page 10
# 1                    18                    42                     28
# 2                    23                    25                     17
# 3                    22                    19                     77
# 4                    23                    19                     38

# %%
df['DE01'] = df['DE01'].replace(['1', '2', '3'], ['Muški', 'Ženski', 'Ne želim da odgovorim'])
# Out:
# C:\Users\saras\AppData\Local\Temp/ipykernel_5116/2664656871.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['DE01'] = df['DE01'].replace(['1', '2', '3'], ['Muški', 'Ženski', 'Ne želim da odgovorim'])

# %%
df['DE03'] = df['DE03'].replace(['1', '2', '3', '4', '5', '6'], [
    'Završena osnovna škola',
    'Završena srednja škola ili gimnazija',
    'Student/kinja',
    'Završen fakultet ili viša škola',
    'Završene master studije',
    'Završene doktorske studije'
])
# Out:
# C:\Users\saras\AppData\Local\Temp/ipykernel_5116/2156891312.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['DE03'] = df['DE03'].replace(['1', '2', '3', '4', '5', '6'], [

# %%
df.head()
# Out:
#                          CASE    DE01  \
# 0  Interview number (ongoing)     Pol
# 1                          87  Ženski
# 2                          93  Ženski
# 3                          94  Ženski
# 4                          95   Muški
#
#                                        LASTDATA       DE02_01           DE03  \
# 0  Time when the data was most recently updated  Godine: [01]    Obrazovanje
# 1                           2022-03-09 22:49:05            19  Student/kinja
# 2                           2022-03-10 01:30:57            19  Student/kinja
# 3                           2022-03-10 08:51:32            19  Student/kinja
# 4                           2022-03-10 09:08:39            20  Student/kinja
#
#         PF02             PF04       PF07     NF01       NF03  \
# 0  Alchemist  Weapons auction  Town hero  Guard N  Butcher N
# 1          2                2          2        1          1
# 2          2                1          2        2          2
# 3          1                2          2        2          1
# 4          2                2          1        1          1
#
#                   NF05        NF06               TIME004  \
# 0  Bandit chase over N  Hospital N  Time spent on page 4
# 1                    1           2                    46
# 2                    1           1                    56
# 3                    2           1                    71
# 4                    1           1                    26
#
#                 TIME005               TIME006               TIME007  \
# 0  Time spent on page 5  Time spent on page 6  Time spent on page 7
# 1                    27                    32                    27
# 2                    55                    27                    44
# 3                    28                    57                    44
# 4                    35                    43                    26
#
#                 TIME008               TIME009                TIME010
# 0  Time spent on page 8  Time spent on page 9  Time spent on page 10
# 1                    18                    42                     28
# 2                    23                    25                     17
# 3                    22                    19                     77
# 4                    23                    19                     38

# %%
df = df.rename(columns={
    'CASE': '_id',
    'DE01': 'gender',
    'DE02_01': 'age',
    'DE03': 'education',
    'NF01': 'answer.Guard',
    'PF02': 'answer.Salesman',
    'NF03': 'answer.Butcher',
    'PF04': 'answer.Auction',
    'NF05': 'answer.Bandits',
    'NF06': 'answer.Doctor',
    'PF07': 'answer.Mayor'
})

# %%
df = df.rename(columns={
    'TIME004': 'time.Guard',
    'TIME005': 'time.Salesman',
    'TIME006': 'time.Butcher',
    'TIME007': 'time.Auction',
    'TIME008': 'time.Bandits',
    'TIME009': 'time.Doctor',
    'TIME010': 'time.Mayor'
})

# %%
df.head()
# Out:
#                           _id  gender  \
# 0  Interview number (ongoing)     Pol
# 1                          87  Ženski
# 2                          93  Ženski
# 3                          94  Ženski
# 4                          95   Muški
#
#                                        LASTDATA           age      education  \
# 0  Time when the data was most recently updated  Godine: [01]    Obrazovanje
# 1                           2022-03-09 22:49:05            19  Student/kinja
# 2                           2022-03-10 01:30:57            19  Student/kinja
# 3                           2022-03-10 08:51:32            19  Student/kinja
# 4                           2022-03-10 09:08:39            20  Student/kinja
#
#   answer.Salesman   answer.Auction answer.Mayor answer.Guard answer.Butcher  \
# 0       Alchemist  Weapons auction    Town hero      Guard N      Butcher N
# 1               2                2            2            1              1
# 2               2                1            2            2              2
# 3               1                2            2            2              1
# 4               2                2            1            1              1
#
#         answer.Bandits answer.Doctor            time.Guard  \
# 0  Bandit chase over N    Hospital N  Time spent on page 4
# 1                    1             2                    46
# 2                    1             1                    56
# 3                    2             1                    71
# 4                    1             1                    26
#
#           time.Salesman          time.Butcher          time.Auction  \
# 0  Time spent on page 5  Time spent on page 6  Time spent on page 7
# 1                    27                    32                    27
# 2                    55                    27                    44
# 3                    28                    57                    44
# 4                    35                    43                    26
#
#            time.Bandits           time.Doctor             time.Mayor
# 0  Time spent on page 8  Time spent on page 9  Time spent on page 10
# 1                    18                    42                     28
# 2                    23                    25                     17
# 3                    22                    19                     77
# 4                    23                    19                     38

# %%
df.drop(df.index[0], inplace=True)

# %%
df.head()
# Out:
#   _id  gender             LASTDATA age      education answer.Salesman  \
# 1  87  Ženski  2022-03-09 22:49:05  19  Student/kinja               2
# 2  93  Ženski  2022-03-10 01:30:57  19  Student/kinja               2
# 3  94  Ženski  2022-03-10 08:51:32  19  Student/kinja               1
# 4  95   Muški  2022-03-10 09:08:39  20  Student/kinja               2
# 5  96  Ženski  2022-03-10 10:50:33  19  Student/kinja               2
#
#   answer.Auction answer.Mayor answer.Guard answer.Butcher answer.Bandits  \
# 1              2            2            1              1              1
# 2              1            2            2              2              1
# 3              2            2            2              1              2
# 4              2            1            1              1              1
# 5              2            1            1              2              2
#
#   answer.Doctor time.Guard time.Salesman time.Butcher time.Auction  \
# 1             2         46            27           32           27
# 2             1         56            55           27           44
# 3             1         71            28           57           44
# 4             1         26            35           43           26
# 5             1         51            43           45           38
#
#   time.Bandits time.Doctor time.Mayor
# 1           18          42         28
# 2           23          25         17
# 3           22          19         77
# 4           23          19         38
# 5           32          37         36

# %%
df.describe()
# Out:
#         _id  gender             LASTDATA  age      education answer.Salesman  \
# count   101     101                  101  100            101              97
# unique  101       3                  101    9              4               2
# top      87  Ženski  2022-03-09 22:49:05   19  Student/kinja               1
# freq      1      89                    1   73             89              59
#
#        answer.Auction answer.Mayor answer.Guard answer.Butcher answer.Bandits  \
# count              93           91           99             94             92
# unique              2            2            2              2              2
# top                 2            2            1              1              1
# freq               53           48           62             66             55
#
#        answer.Doctor time.Guard time.Salesman time.Butcher time.Auction  \
# count             91         99            97           94           93
# unique             2         56            47           59           47
# top                1         26            25            2           12
# freq              52          6             5            5            5
#
#        time.Bandits time.Doctor time.Mayor
# count            92          91         91
# unique           38          40         48
# top               1           2          1
# freq              8           7          9

# %%
df
# Out:
#      _id  gender             LASTDATA age      education answer.Salesman  \
# 1     87  Ženski  2022-03-09 22:49:05  19  Student/kinja               2
# 2     93  Ženski  2022-03-10 01:30:57  19  Student/kinja               2
# 3     94  Ženski  2022-03-10 08:51:32  19  Student/kinja               1
# 4     95   Muški  2022-03-10 09:08:39  20  Student/kinja               2
# 5     96  Ženski  2022-03-10 10:50:33  19  Student/kinja               2
# ..   ...     ...                  ...  ..            ...             ...
# 97   221  Ženski  2022-03-20 17:28:51  20  Student/kinja               1
# 98   222  Ženski  2022-03-20 18:04:48  19  Student/kinja               2
# 99   224  Ženski  2022-03-20 20:29:29  19  Student/kinja               1
# 100  225  Ženski  2022-03-20 20:39:54  19  Student/kinja               1
# 101  226   Muški  2022-03-20 23:20:02  19  Student/kinja               1
#
#     answer.Auction answer.Mayor answer.Guard answer.Butcher answer.Bandits  \
# 1                2            2            1              1              1
# 2                1            2            2              2              1
# 3                2            2            2              1              2
# 4                2            1            1              1              1
# 5                2            1            1              2              2
# ..             ...          ...          ...            ...            ...
# 97               2            1            2              1              1
# 98               2            2            2              2              1
# 99               2            2            2              1              2
# 100              2            2            1              1              1
# 101              1            2            1              2              2
#
#     answer.Doctor time.Guard time.Salesman time.Butcher time.Auction  \
# 1               2         46            27           32           27
# 2               1         56            55           27           44
# 3               1         71            28           57           44
# 4               1         26            35           43           26
# 5               1         51            43           45           38
# ..            ...        ...           ...          ...          ...
# 97              2         50            38           43           43
# 98              2         25            10           23           10
# 99              1         34            34          225           30
# 100             2          8            11            7           12
# 101             2         73            10           34           14
#
#     time.Bandits time.Doctor time.Mayor
# 1             18          42         28
# 2             23          25         17
# 3             22          19         77
# 4             23          19         38
# 5             32          37         36
# ..           ...         ...        ...
# 97            30          34         45
# 98            12           6          4
# 99             2          17         32
# 100           13          10         14
# 101            8           4          1
#
# [101 rows x 19 columns]

# %%
df = df.dropna()
df
# Out:
#      _id  gender             LASTDATA age      education answer.Salesman  \
# 1     87  Ženski  2022-03-09 22:49:05  19  Student/kinja               2
# 2     93  Ženski  2022-03-10 01:30:57  19  Student/kinja               2
# 3     94  Ženski  2022-03-10 08:51:32  19  Student/kinja               1
# 4     95   Muški  2022-03-10 09:08:39  20  Student/kinja               2
# 5     96  Ženski  2022-03-10 10:50:33  19  Student/kinja               2
# ..   ...     ...                  ...  ..            ...             ...
# 97   221  Ženski  2022-03-20 17:28:51  20  Student/kinja               1
# 98   222  Ženski  2022-03-20 18:04:48  19  Student/kinja               2
# 99   224  Ženski  2022-03-20 20:29:29  19  Student/kinja               1
# 100  225  Ženski  2022-03-20 20:39:54  19  Student/kinja               1
# 101  226   Muški  2022-03-20 23:20:02  19  Student/kinja               1
#
#     answer.Auction answer.Mayor answer.Guard answer.Butcher answer.Bandits  \
# 1                2            2            1              1              1
# 2                1            2            2              2              1
# 3                2            2            2              1              2
# 4                2            1            1              1              1
# 5                2            1            1              2              2
# ..             ...          ...          ...            ...            ...
# 97               2            1            2              1              1
# 98               2            2            2              2              1
# 99               2            2            2              1              2
# 100              2            2            1              1              1
# 101              1            2            1              2              2
#
#     answer.Doctor time.Guard time.Salesman time.Butcher time.Auction  \
# 1               2         46            27           32           27
# 2               1         56            55           27           44
# 3               1         71            28           57           44
# 4               1         26            35           43           26
# 5               1         51            43           45           38
# ..            ...        ...           ...          ...          ...
# 97              2         50            38           43           43
# 98              2         25            10           23           10
# 99              1         34            34          225           30
# 100             2          8            11            7           12
# 101             2         73            10           34           14
#
#     time.Bandits time.Doctor time.Mayor
# 1             18          42         28
# 2             23          25         17
# 3             22          19         77
# 4             23          19         38
# 5             32          37         36
# ..           ...         ...        ...
# 97            30          34         45
# 98            12           6          4
# 99             2          17         32
# 100           13          10         14
# 101            8           4          1
#
# [91 rows x 19 columns]

# %%
df = df.drop(columns=['_id'])

# %%
sorted_columns = ['age', 'education', 'gender', 'answer.Auction', 'time.Auction',
       'answer.Bandits', 'time.Bandits', 'answer.Butcher', 'time.Butcher',
       'answer.Doctor', 'time.Doctor', 'answer.Guard', 'time.Guard',
       'answer.Mayor', 'time.Mayor', 'answer.Salesman', 'time.Salesman']

df = df.reindex(columns=sorted_columns)

# %%
df.to_excel('upitnik_odgovori_clean.xlsx', index=False, encoding='utf16')
